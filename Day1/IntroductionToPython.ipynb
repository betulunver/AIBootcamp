# %% [markdown]
# #INTRODUCTION TO PYTHON

# %% [markdown]
# LATEX $\int$ $ \int^b_a \frac{dx}{tanhx}\Sigma \aplha \beta \theta$

# %%
5+5
# buraya not alabialirsin.
# Out:
# 10

# %%
print("Hello Data Scientist")
# Out:
# Hello Data Scientist

# %%
print("Betül Ünver "*1000)
"Betül Ünver "*1000
# Out:
# Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Betül Ünver Be
# ...

# %%
for  i in range(1000):
    print("hellloo")
# Out:
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# hellloo
# ...

# %% [markdown]
# #DEĞİŞKEN

# %%
a=5

# %%
a*5
# Out:
# 25

# %%
b=3
c=a+b

# %%
c
# Out:
# 8

# %%
liste=["Ali","Veli","Ayse"]

# %%
for i in liste:
    print(i)
# Out:
# Ali
# Veli
# Ayse

# %%
'Ali dedi ki "Merhaba"'
# Out:
# 'Ali dedi ki "Merhaba"'

# %%
yil=2022

# %%
ay="Ekim"

# %% [markdown]
# ### OPERATORLAR

# %%
# + - / * = % **

# %%
5+5
# Out:
# 10

# %%
5-5
# Out:
# 0

# %%
5/5
# Out:
# 1.0

# %%
5*5
# Out:
# 25

# %%
5%2
# Out:
# 1

# %%
5**5
# Out:
# 3125

# %% [markdown]
# ### logic operatorlar

# %%
#<, >, <=, >=, == != and or & |

# %%
note = int(input("Notunuzu Giriniz: "))
# Out:
# Notunuzu Giriniz:  85

# %%
if note>=90:
    print("A")
elif note >= 80:
    print("B")
else: 
    print("F")
# Out:
# B

# %%
#DRY = Don not repeat yourself

# %%
for i in range(101):
    print(i**2)
# Out:
# 0
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 100
# 121
# 144
# 169
# 196
# 225
# 256
# 289
# 324
# 361
# 400
# 441
# 484
# 529
# 576
# 625
# 676
# 729
# 784
# 841
# 900
# 961
# 1024
# 1089
# 1156
# 1225
# 1296
# 1369
# 1444
# 1521
# 1600
# 1681
# 1764
# 1849
# 1936
# 2025
# 2116
# 2209
# 2304
# 2401
# 2500
# 2601
# 2704
# 2809
# 2916
# 3025
# 3136
# 3249
# 3364
# 3481
# 3600
# 3721
# 3844
# 3969
# 4096
# 4225
# 4356
# 4489
# 4624
# 4761
# 4900
# 5041
# 5184
# 5329
# 5476
# 5625
# 5776
# 5929
# 6084
# 6241
# 6400
# 6561
# 6724
# 6889
# 7056
# 7225
# 7396
# 7569
# 7744
# 7921
# 8100
# 8281
# 8464
# 8649
# 8836
# 9025
# 9216
# 9409
# 9604
# 9801
# 10000

# %%
#EDA

# %%
#!pip install pandas

# %%
import pandas as pd

# %%
df=pd.read_csv("train.csv")

# %%
df.tail()
#son 5 lişiyi getiriyor
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.sample(200)
#içinden rastgele 200 kişi getirecek
# Out:
#      PassengerId  Survived  Pclass  \
# 844          845         0       3
# 684          685         0       2
# 577          578         1       1
# 877          878         0       3
# 854          855         0       2
# ..           ...       ...     ...
# 326          327         0       3
# 199          200         0       2
# 420          421         0       3
# 455          456         1       3
# 218          219         1       1
#
#                                               Name     Sex   Age  SibSp  \
# 844                            Culumovic, Mr. Jeso    male  17.0      0
# 684              Brown, Mr. Thomas William Solomon    male  60.0      1
# 577      Silvey, Mrs. William Baird (Alice Munger)  female  39.0      1
# 877                           Petroff, Mr. Nedelio    male  19.0      0
# 854  Carter, Mrs. Ernest Courtenay (Lilian Hughes)  female  44.0      1
# ..                                             ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
#boş olan satırların sayısını veriyor
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df["Sex"].value_counts()
#kaç tane erkek kadın veriyor
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df["Embarked"].value_counts()
#hangi limandan kaç kişi binmiş
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df["Age"].hist()
# Out:
# <AxesSubplot: >

# %%
df["Age"].max()
# Out:
# 80.0

# %%
df["Age"].min()
# Out:
# 0.42

# %%
#!pip install seaborn

# %%
import seaborn as sns

# %%
sns.pairplot(df, hue="Survived")

# %%
df[df["Age"]<18]
#yaşı 18den lküçük olnaları listele
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 9             10         1       2      Nasser, Mrs. Nicholas (Adele Achem)
# 10            11         1       3          Sandstrom, Miss. Marguerite Rut
# 14            15         0       3     Vestrom, Miss. Hulda Amanda Adolfina
# 16            17         0       3                     Rice, Master. Eugene
# ..           ...       ...     ...                                      ...
# 850          851         0       3  Andersson, Master. Sigvard Harald Elias
# 852          853         0       3                  Boulos, Miss. Nourelain
# 853          854         1       1                Lines, Miss. Mary Conover
# 869          870         1       3          Johnson, Master. Harold Theodor
# 875          876         1       3         Najib, Miss. Adele Kiamie "Jane"
#
# ...

# %%
df[(df["Age"]<18) & (df["Pclass"]==3)]
#yaşı 18den küçük ve 3.sınıf yolcu olanları listele
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 10            11         1       3          Sandstrom, Miss. Marguerite Rut
# 14            15         0       3     Vestrom, Miss. Hulda Amanda Adolfina
# 16            17         0       3                     Rice, Master. Eugene
# 22            23         1       3              McGowan, Miss. Anna "Annie"
# ..           ...       ...     ...                                      ...
# 844          845         0       3                      Culumovic, Mr. Jeso
# 850          851         0       3  Andersson, Master. Sigvard Harald Elias
# 852          853         0       3                  Boulos, Miss. Nourelain
# 869          870         1       3          Johnson, Master. Harold Theodor
# 875          876         1       3         Najib, Miss. Adele Kiamie "Jane"
#
# ...

# %%
#pip install --upgrade xlrd
# Out:
# Note: you may need to restart the kernel to use updated packages.
# 'c:\program' is not recognized as an internal or external command,
# operable program or batch file.

# %%
df=pd.read_excel("sales-funnel.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\compat\_optional.py in import_optional_dependency(name, extra, errors, min_version)
#     141     try:
# --> 142         module = importlib.import_module(name)
#     143     except ImportError:
#
# c:\program files\python38\lib\importlib\__init__.py in import_module(name, package)
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#
# c:\program files\python38\lib\importlib\_bootstrap.py in _gcd_import(name, package, level)
#
# c:\program files\python38\lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# c:\program files\python38\lib\importlib\_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# ...

# %%
df.describe()
# bütün sutunların(sayısal veri olanların) kaç tane elemanı, standart sapması min max hepsini hesaplıyor

# %%
pip install gtts
# Out:
# Note: you may need to restart the kernel to use updated packages.
# 'c:\program' is not recognized as an internal or external command,
# operable program or batch file.

# %%
from gtts import gTTS
text="Welcome to our best data science class"
kayit= gTTS(text=text,lang="en", slow=False)
kayit.save("konusma.mp3")
