# %%
import numpy as np
#veri görselleştirmek için gerekli paket
import pandas as pd
#dosyalardan veri alabilmek için paket
import matplotlib.pyplot as plt

# %%
x=np.arange(20)
#0-20 arası sayı oluşturuyor
y=np.random.normal(10,1,20)
#normal dağılım(sağı solu eşit), ort 10 standart sapması 1 20 tane sayı
z=np.random.normal(10,2,20)
k=np.random.normal(10,3,20)

# %%
plt.plot(x,y, color='r') # r ile başlayan tek renk var red
plt.plot(x,z)
# aynı hücrede yazarsan aynı grafikte gösteririr.
plt.plot(x,k);
# son satırın sonuna ";" koyarsan uyarı çıkmaz

# %%
np.random.seed(34) #eğer ki biz bu şekilde kullanırsak diğer kişilerde de grafik aynı olur. çünkü 34 'ü baz alır.

# %%
fig=plt.figure(figsize=(10,6)) #figsize grafiğin boyutunu ayarlamak için
#eğer ki yan yana birden fazla grafik oluşturmak istiyorsak figure eklemeliyiz.
ax=fig.add_subplot(131) # 1 sutun 3 satır
ax.set_title("x'in y'ye göre değişimi")
ax.set_xlabel("X Verileri")
ax.set_ylabel("Y verileri")
ax.plot(x,y)
bx=fig.add_subplot(132) #3 satır 1 sütun
cx.set_title("x'in b'ye göre değişimi")
bx.plot(x,z)
cx=fig.add_subplot(133)
cx.set_title("x'in k'ye göre değişimi")
cx.plot(x,k);
#grafikler alt alta olsun isteresek hepsni 3 satır 1 stun olacak şekilde ayarlayabiliriz (311) gibi

# %%
l=np.linspace(10,20,10000) #10-20 arasında 10000 rakam üretmek için

# %%
m=np.linspace(0,10,10000)

# %%
plt.plot(l, np.cos(m), linestyle="dashed")
plt.plot(l,np.sin(m),linestyle="dotted", color="#FFDD44", marker="v");
plt.savefig("figure1.jpg",dpi=300) # kaydetme formatını belirtiyoruz, dpi=300 baskı kalitsinde olmasnı sağlıyor. Dergiye verebilir, baskıya gidebilir bir dosya oldu

# %%
plt.scatter(x,y, marker ="^", color='r') #d diamond, v baklava dilimi gibi, ^ yukarı doğru
plt.xlabel("X değerleri")
plt.ylabel("Y label")
plt.title("X vs Y");

# %%
plt.boxplot(x) #verinin ortlaması kaç min max yüzde olarak nerede onu gösteriyror.
plt.boxplot(y);

# %%
plt.boxplot([x,y]);

# %%
plt.hist(y);
# Out:
# (array([1., 0., 0., 3., 6., 2., 5., 0., 0., 3.]),
#  array([ 7.46086376,  7.96398459,  8.46710542,  8.97022625,  9.47334708,
#          9.97646791, 10.47958874, 10.98270957, 11.4858304 , 11.98895124,
#         12.49207207]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(z) #histogram bize verinin nasıl dağılıdğını gösteriyor
# Out:
# (array([1., 2., 1., 2., 1., 1., 2., 3., 2., 5.]),
#  array([ 5.60528652,  6.31553044,  7.02577435,  7.73601827,  8.44626219,
#          9.15650611,  9.86675003, 10.57699394, 11.28723786, 11.99748178,
#         12.7077257 ]),
#  <BarContainer object of 10 artists>)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as od

# %%
df=pd.read_csv("supermarket.csv") # data frame => excel dsoyssını ram'e aktarmak

# %%
#EDA - Exploratory Data Analysis

# %%
df.head(50) # hiç bir şey yazmazsan 5 tane
# Out:
#      Invoice ID Branch       City Customer type  Gender  \
# 0   750-67-8428      A     Yangon        Member  Female
# 1   226-31-3081      C  Naypyitaw        Normal  Female
# 2   631-41-3108      A     Yangon        Normal    Male
# 3   123-19-1176      A     Yangon        Member    Male
# 4   373-73-7910      A     Yangon        Normal    Male
# 5   699-14-3026      C  Naypyitaw        Normal    Male
# 6   355-53-5943      A     Yangon        Member  Female
# 7   315-22-5665      C  Naypyitaw        Normal  Female
# 8   665-32-9167      A     Yangon        Member  Female
# 9   692-92-5582      B   Mandalay        Member  Female
# 10  351-62-0822      B   Mandalay        Member  Female
# 11  529-56-3974      B   Mandalay        Member    Male
# 12  365-64-0515      A     Yangon        Normal  Female
# 13  252-56-2699      A     Yangon        Normal    Male
# 14  829-34-3910      A     Yangon        Normal  Female
# 15  299-46-1805      B   Mandalay        Member  Female
# ...

# %%
df.sample()
# Out:
#       Invoice ID Branch      City Customer type Gender         Product line  \
# 430  286-75-7818      B  Mandalay        Normal   Male  Fashion accessories
#
#      Unit price  Quantity  Tax 5%    Total       Date   Time      Payment  \
# 430       69.08         2   6.908  145.068  1/31/2019  19:48  Credit card
#
#        cogs  gross margin percentage  gross income  Rating
# 430  138.16                 4.761905         6.908     6.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905     15.379369     6.97270
# std                   0.000000     11.708825     1.71858
# min                   4.761905      0.508500     4.00000
# ...

# %%
df.corr() # correlation -> bir olayın diğer olaya ne kadar bağlı olduğu
# Out:
# <ipython-input-47-539438f469d9>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr() # correlation
#                          Unit price  Quantity    Tax 5%     Total      cogs  \
# Unit price                 1.000000  0.010778  0.633962  0.633962  0.633962
# Quantity                   0.010778  1.000000  0.705510  0.705510  0.705510
# Tax 5%                     0.633962  0.705510  1.000000  1.000000  1.000000
# Total                      0.633962  0.705510  1.000000  1.000000  1.000000
# cogs                       0.633962  0.705510  1.000000  1.000000  1.000000
# gross margin percentage         NaN       NaN       NaN       NaN       NaN
# gross income               0.633962  0.705510  1.000000  1.000000  1.000000
# Rating                    -0.008778 -0.015815 -0.036442 -0.036442 -0.036442
#
# ...

# %%
sns.heatmap(df.corr(), annot=True) # bu da grafikle gösterimi, annot grafiğe verileri rakamalrı diye
# Out:
# <ipython-input-50-c2ca84c2a0d6>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True) # bu da grafikle gösterimi
# <AxesSubplot: >

# %%
df['City'].unique()
# Out:
# array(['Yangon', 'Naypyitaw', 'Mandalay'], dtype=object)

# %%
df.City.nunique() # sayısını veriyor
# Out:
# 3

# %%
df.Total.min()
# Out:
# 10.6785

# %%
df.Total.max()
# Out:
# 1042.65

# %%
df.Total.mean()
# Out:
# 322.966749

# %%
df.Total.min(),df.Total.max(),df.Total.mean() # virgül ile hepsini tek seferde yazdırabiliriz.
# Out:
# (10.6785, 1042.65, 322.966749)

# %%
#Feature Engineering - Verinin Aslında olmayan ancak verilen yararlanilip üretilen sutun işlemine denir. Öznitelik Müh.

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df['day']=(df['Date']).dt.day
df['month']=(df['Date']).dt.month
df['year']=(df['Date']).dt.year

# %%
df['month_name']=df['Date'].dt.month_name()
df['weekday']=df['Date'].dt.day_name()

# %%
df["Time"]=pd.to_datetime(df['Time'])

# %%
df["Hour"]=df['Time'].dt.hour

# %%
sns.countplot(x=df["month_name"]); #aylara göre satış

# %%
sns.countplot(x=df["Gender"], cmap=''); # x ekseni

# %%
sns.countplot(x=df['weekday'])
# Out:
# <AxesSubplot: xlabel='weekday', ylabel='count'>

# %%
sns.countplot(x=df['weekday'])
plt.xticks(rotation=45); # kolon isimleri açılı yazılsın diye

# %%
sns.countplot(x=df['Product line'])
plt.xticks(rotation=90); # kolon isimleri açılı yazılsın diye

# %%
plt.figure(figsize=(12,6))
plt.title("Total Monthly Transaction")
sns.countplot(x=df['Product line'])
plt.xticks(rotation=90);

# %%
plt.figure(figsize=(12,6))
plt.title("Total Monthly Transaction")
sns.countplot(x=df['Product line'], hue=df.Gender); # cinsiyete göre hangi üründen kim ne kadar almış
plt.xticks(rotation=90);

# %%
plt.figure(figsize=(12,6))
plt.title("Total Monthly Transaction")
sns.countplot(x=df['Branch'], hue=df.Gender);
plt.xticks(rotation=90);

# %%
plt.figure(figsize=(12,6))
plt.title("Total Monthly Transaction")
sns.countplot(x=df["Branch"], hue=df['Product line'])
plt.xticks(rotation=90); 
plt.legend(loc=0) #tablo bilgisinin lokasyounu ayarlayabiliyoruz. best=0, upper=1 gibi

# %%
sns.countplot(x=df["Customer type"]) #üye olan ve normal müşteri sayısı
# Out:
# <AxesSubplot: xlabel='Customer type', ylabel='count'>

# %%
sns.barplot(x=df.City,y=df.index) #
# Out:
# <AxesSubplot: xlabel='City'>

# %%
sns.boxplot(x=df["Total"])
# Out:
# <AxesSubplot: xlabel='Total'>

# %%
# grafikte outliner olanlar var 1000 rakakmında

# %%
df[df.Total>1000] # 1000 lira üzerinde alışveriş yapanları görelim
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 166  234-65-2137      C  Naypyitaw        Normal    Male   Home and lifestyle
# 167  687-47-8271      A     Yangon        Normal    Male  Fashion accessories
# 350  860-79-0874      C  Naypyitaw        Member  Female  Fashion accessories
# 357  554-42-2417      C  Naypyitaw        Normal  Female    Sports and travel
# 422  271-88-8734      C  Naypyitaw        Member  Female  Fashion accessories
# 557  283-26-5248      C  Naypyitaw        Member  Female   Food and beverages
# 699  751-41-9720      C  Naypyitaw        Normal    Male   Home and lifestyle
# 792  744-16-7898      B   Mandalay        Normal  Female   Home and lifestyle
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
#
#      Unit price  Quantity  Tax 5%     Total  ...   cogs  \
# 166       95.58        10  47.790  1003.590  ...  955.8
# 167       98.98        10  49.490  1039.290  ...  989.8
# ...

# %%
sns.countplot(x=df.Payment)
# Out:
# <AxesSubplot: xlabel='Payment', ylabel='count'>

# %%
df.Payment.value_counts()
# Out:
# Ewallet        345
# Cash           344
# Credit card    311
# Name: Payment, dtype: int64

# %%
#hangi ürünlerden ne kadar para kazandığımızı bulalım
plt.figure(figsize=(12,6))
sns.barplot(x=df["Product line"], y=df["gross income"])
# Out:
# <AxesSubplot: xlabel='Product line', ylabel='gross income'>

# %%
df['Hour'].unique() # market açılış kapanış tahmini yapabiliriz
# Out:
# array([13, 10, 20, 18, 14, 11, 17, 16, 19, 15, 12], dtype=int64)

# %%
sns.boxplot(x="Branch",y="Rating", data=df)
# Out:
# <AxesSubplot: xlabel='Branch', ylabel='Rating'>

# %%
sns.lineplot(x="Hour",y="Quantity", data=df)
# Out:
# <AxesSubplot: xlabel='Hour', ylabel='Quantity'>

# %%
sns.relplot(x="Hour", y="Quantity", col="month", row="Branch", kind="line", hue="Gender", data=df)

# %%
sns.pairplot(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1a6fe1782b2f> in <module>
# ----> 1 sns.pairplot(df)
#
# NameError: name 'sns' is not defined
